# %%
from dao import VentaDAO
# Out:
# entering headquarters config
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~/.local/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~/.local/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1049, "Unknown database 'Cassatta'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-071c2f7303c4> in <module>
# ----> 1 from dao import VentaDAO
#
# ~/Documentos/Cassatta/PythonCassatta/dao.py in <module>
#      10
#      11 from db_models.productos import Productos
# ---> 12 from db_models.ventas import Ventas
#      13 from db_models.ventas_detalles import VentasDetalles
#      14 from db_models.clientes import Clientes
#
# ~/Documentos/Cassatta/PythonCassatta/db_models/ventas.py in <module>
#       3
#       4
# ----> 5 from . import clientes
#       6 from config_vars import BBDD_CONNECTION
#       7
#
# ~/Documentos/Cassatta/PythonCassatta/db_models/clientes.py in <module>
#       6
#       7
# ----> 8 class Clientes(Base):
#       9     __tablename__ = "clientes"
#      10     print("entering headquarters config")
#
# ~/Documentos/Cassatta/PythonCassatta/db_models/clientes.py in Clientes()
#      11     engine = create_engine(BBDD_CONNECTION)
#      12     metadata = MetaData()
# ---> 13     cli = Table("clientes", metadata, autoload=True, autoload_with=engine, schema='Cassatta')
#      14     id_not_in_db = Column(Integer, primary_key=True)
#      15     print("finished config for clientes")
#
# <string> in __new__(cls, *args, **kw)
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in __new__(cls, *args, **kw)
#     599             except Exception:
#     600                 with util.safe_reraise():
# --> 601                     metadata._remove_table(name, schema)
#     602
#     603     def __init__(self, *args, **kw):
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in __new__(cls, *args, **kw)
#     594             metadata._add_table(name, schema, table)
#     595             try:
# --> 596                 table._init(name, metadata, *args, **kw)
#     597                 table.dispatch.after_parent_attach(table, metadata)
#     598                 return table
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in _init(self, name, metadata, *args, **kwargs)
#     669         # circular foreign keys
#     670         if autoload:
# --> 671             self._autoload(
#     672                 metadata,
#     673                 autoload_with,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/sql/schema.py in _autoload(self, metadata, autoload_with, include_columns, exclude_columns, resolve_fks, _extend_on)
#     704         insp = inspection.inspect(autoload_with)
#     705         with insp._inspection_context() as conn_insp:
# --> 706             conn_insp.reflect_table(
#     707                 self,
#     708                 include_columns,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in reflect_table(self, table, include_columns, exclude_columns, resolve_fks, _extend_on)
#     755
#     756         # reflect table options, like mysql_engine
# --> 757         tbl_opts = self.get_table_options(
#     758             table_name, schema, **table.dialect_kwargs
#     759         )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in get_table_options(self, table_name, schema, **kw)
#     396         if hasattr(self.dialect, "get_table_options"):
#     397             with self._operation_context() as conn:
# --> 398                 return self.dialect.get_table_options(
#     399                     conn, table_name, schema, info_cache=self.info_cache, **kw
#     400                 )
#
# <string> in get_table_options(self, connection, table_name, schema, **kw)
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in cache(fn, self, con, *args, **kw)
#      53     ret = info_cache.get(key)
#      54     if ret is None:
# ---> 55         ret = fn(self, con, *args, **kw)
#      56         info_cache[key] = ret
#      57     return ret
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/base.py in get_table_options(self, connection, table_name, schema, **kw)
#    3059     def get_table_options(self, connection, table_name, schema=None, **kw):
#    3060
# -> 3061         parsed_state = self._parsed_state_or_create(
#    3062             connection, table_name, schema, **kw
#    3063         )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/base.py in _parsed_state_or_create(self, connection, table_name, schema, **kw)
#    3308         self, connection, table_name, schema=None, **kw
#    3309     ):
# -> 3310         return self._setup_parser(
#    3311             connection,
#    3312             table_name,
#
# <string> in _setup_parser(self, connection, table_name, schema, **kw)
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/reflection.py in cache(fn, self, con, *args, **kw)
#      53     ret = info_cache.get(key)
#      54     if ret is None:
# ---> 55         ret = fn(self, con, *args, **kw)
#      56         info_cache[key] = ret
#      57     return ret
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/base.py in _setup_parser(self, connection, table_name, schema, **kw)
#    3335             )
#    3336         )
# -> 3337         sql = self._show_create_table(
#    3338             connection, None, charset, full_name=full_name
#    3339         )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/base.py in _show_create_table(self, connection, table, charset, full_name)
#    3434         rp = None
#    3435         try:
# -> 3436             rp = connection.execution_options(
#    3437                 skip_user_error_events=True
#    3438             ).exec_driver_sql(st)
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in exec_driver_sql(self, statement, parameters, execution_options)
#    1636         args_10style, kwargs_10style = _distill_params_20(parameters)
#    1637
# -> 1638         return self._exec_driver_sql(
#    1639             statement,
#    1640             args_10style,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1545
#    1546         dialect = self.dialect
# -> 1547         ret = self._execute_context(
#    1548             dialect,
#    1549             dialect.execution_ctx_cls._init_statement,
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1812
#    1813         except BaseException as e:
# -> 1814             self._handle_dbapi_exception(
#    1815                 e, statement, parameters, cursor, context
#    1816             )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1993                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1994             elif should_wrap:
# -> 1995                 util.raise_(
#    1996                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1997                 )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769                             break
#    1770                 if not evt_handled:
# -> 1771                     self.dialect.do_execute(
#    1772                         cursor, statement, parameters, context
#    1773                     )
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
# --> 717         cursor.execute(statement, parameters)
#     718
#     719     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~/.local/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~/.local/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~/.local/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~/.local/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1049, "Unknown database 'Cassatta'")
# [SQL: SHOW CREATE TABLE `Cassatta`.`clientes`]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
data = HospitalDAO()
esps = data.get_medical_specialities(heq_id=2)
response = "Tenemos las siguientes especialidades: "

for e in esps:
    response += e[1]+", "

print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e0701deb4f51> in <module>
# ----> 1 data = HospitalDAO()
#       2 esps = data.get_medical_specialities(heq_id=2)
#       3 response = "Tenemos las siguientes especialidades: "
#       4
#       5 for e in esps:
#
# NameError: name 'HospitalDAO' is not defined

# %%
doctors = data.get_doctors(heq_id=2)
specialities = data.get_medical_specialities()

# %%
doctors
# Out:
# [(Decimal('1'), 'Chamale', 'Oscar Elías', Decimal('1')),
#  (Decimal('2'), 'Lozano', 'Alejandro', Decimal('2')),
#  (Decimal('4'), 'Bertolino', 'María Lorena', Decimal('3')),
#  (Decimal('5'), 'Consigli', 'Nicolas Ernesto', Decimal('4')),
#  (Decimal('7'), 'Bartolacci', 'Inés', Decimal('6')),
#  (Decimal('8'), 'Majul', 'Enrique', Decimal('6'))]

# %%
specialities
# Out:
# [(Decimal('1'), 'CLINICA MEDICA', Decimal('1')),
#  (Decimal('2'), 'ALERGIA E INMUNOLOGIA', Decimal('1')),
#  (Decimal('3'), 'ENDOCRINOLOGIA', Decimal('1')),
#  (Decimal('4'), 'DERMATOLOGIA', Decimal('1')),
#  (Decimal('5'), 'SALUD MENTAL', Decimal('1')),
#  (Decimal('6'), 'DIABETES', Decimal('1')),
#  (Decimal('7'), 'Alergia e Inmunología', Decimal('2')),
#  (Decimal('8'), 'Anatomía Patológica', Decimal('2')),
#  (Decimal('9'), 'Anestesiología', Decimal('2')),
#  (Decimal('10'), 'Cardiología', Decimal('2')),
#  (Decimal('11'), 'Cirugía Cardíaca', Decimal('2'))]

# %%
suc = data.get_headquarters(heq_id=1)

# %%
suc
# Out:
# [(Decimal('1'), 'Sede Central', 'Oncativo Nº1248 Bº General Paz', 'Córdoba', 'Argentina', Decimal('1'))]
